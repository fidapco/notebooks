# %% [markdown]
# # Data catalog
#
# In this notebook, we'll explore all the data in Fidap. There are two key tables that contain the metadata -

# %% [markdown]
#  - ``meta_tables`` which contains details about the tables, and
#  - ``meta_fields`` which contains details about the fields

# %%
import pandas as pd
from fidap import fidap_client
import config

# %% [markdown]
# #### Initiat the fidap_client

# %%
fidap = fidap_client(api_key=config.FIDAP_API_KEY)

# %%
fidap.sql("select * from meta_tables")
# Out:
#          table_catalog  table_schema                 table_name   row_count  \
# 0   FIDAP_DATA_SOURCES  FIDAP_SCHEMA                    ACTIONS    139329.0
# 1   FIDAP_DATA_SOURCES  FIDAP_SCHEMA                 CENSUSDATA    298080.0
# 2   FIDAP_DATA_SOURCES  FIDAP_SCHEMA                       CORR     43110.0
# 3   FIDAP_DATA_SOURCES  FIDAP_SCHEMA                 CRYPTODATA      4708.0
# 4   FIDAP_DATA_SOURCES  FIDAP_SCHEMA                      DAILY  18042804.0
# 5   FIDAP_DATA_SOURCES  FIDAP_SCHEMA                      DATES      1278.0
# 6   FIDAP_DATA_SOURCES  FIDAP_SCHEMA                     EVENTS    484349.0
# 7   FIDAP_DATA_SOURCES  FIDAP_SCHEMA       FIDAP_PEOPLEDATALABS         NaN
# 8   FIDAP_DATA_SOURCES  FIDAP_SCHEMA               FUNDAMENTALS    430420.0
# 9   FIDAP_DATA_SOURCES  FIDAP_SCHEMA             INSIDER_TRADES   7223907.0
# 10  FIDAP_DATA_SOURCES  FIDAP_SCHEMA                META_FIELDS       473.0
# 11  FIDAP_DATA_SOURCES  FIDAP_SCHEMA    META_FIELDS_META_FIELDS         9.0
# 12  FIDAP_DATA_SOURCES  FIDAP_SCHEMA            META_FIELDS_NEW       769.0
# 13  FIDAP_DATA_SOURCES  FIDAP_SCHEMA                META_TABLES        10.0
# 14  FIDAP_DATA_SOURCES  FIDAP_SCHEMA            META_TABLES_NEW        25.0
# 15  FIDAP_DATA_SOURCES  FIDAP_SCHEMA           META_TABLES_VIEW         NaN
# 16  FIDAP_DATA_SOURCES  FIDAP_SCHEMA           PEOPLE_DATA_LABS   1794662.0
# 17  FIDAP_DATA_SOURCES  FIDAP_SCHEMA                 PORTFOLIOS    135561.0
# 18  FIDAP_DATA_SOURCES  FIDAP_SCHEMA          PORTFOLIO_DETAILS  35948220.0
# 19  FIDAP_DATA_SOURCES  FIDAP_SCHEMA         RAW_PEOPLEDATALABS   8567134.0
# 20  FIDAP_DATA_SOURCES  FIDAP_SCHEMA                      SP500     10604.0
# 21  FIDAP_DATA_SOURCES  FIDAP_SCHEMA                    TICKERS      6078.0
# 22  FIDAP_DATA_SOURCES  FIDAP_SCHEMA        TICKER_SHAREHOLDERS    366091.0
# 23  FIDAP_DATA_SOURCES  FIDAP_SCHEMA  WALLSTREETBETS_WEEKLY_TOP         9.0
# 24  FIDAP_DATA_SOURCES  FIDAP_SCHEMA         WIKIDATA_COMPANIES      6282.0
#
#            bytes  column_count   datapoints             description
# 0   1.440256e+06             7     975303.0  N.A update if required
# 1   1.013197e+07            17    5067360.0  N.A update if required
# 2   4.725760e+05             3     129330.0  N.A update if required
# 3   2.769920e+05            13      61204.0  N.A update if required
# 4   2.329843e+09            40  721712160.0  N.A update if required
# 5   1.792000e+04             3       3834.0  N.A update if required
# 6   2.043392e+06             3    1453047.0  N.A update if required
# 7            NaN            11          NaN  N.A update if required
# 8   1.555558e+08           113   48637460.0  N.A update if required
# 9   2.408422e+08            24  173373768.0  N.A update if required
# 10  3.020800e+04             9       4257.0  N.A update if required
# 11  4.608000e+03            31        279.0  N.A update if required
# 12  7.168000e+04            31      23839.0  N.A update if required
# 13  2.048000e+03             7         70.0  N.A update if required
# 14  2.048000e+03             8        200.0  N.A update if required
# 15           NaN             8          NaN  N.A update if required
# 16  2.816251e+08            17   30509254.0  N.A update if required
# 17  8.631296e+06            28    3795708.0  N.A update if required
# 18  4.166953e+08             7  251637540.0  N.A update if required
# 19  3.228022e+09             1    8567134.0  N.A update if required
# 20  3.788800e+04             7      74228.0  N.A update if required
# 21  5.461504e+06           209    1270302.0  N.A update if required
# 22  2.130944e+07            29   10616639.0  N.A update if required
# 23  1.024000e+03             4         36.0  N.A update if required
# 24  2.114560e+05            14      87948.0  N.A update if required

# %% [markdown]
# If we wanted to drill down into any individual table, all we need to do is select the fields from that table, as below -

# %%
fidap.sql('select * from meta_fields where "table" = \'fundamentals\' limit 10')
# Out:
#           table          NAME                            DISPLAY_NAME  ... UNIQUENESS          MEAN       MEDIAN
# 0  fundamentals        ticker                           Ticker Symbol  ...   0.016756           NaN          NaN
# 1  fundamentals     dimension                               Dimension  ...   0.000014           NaN          NaN
# 2  fundamentals  calendardate                           Calendar Date  ...   0.000046           NaN          NaN
# 3  fundamentals       datekey                                Date Key  ...   0.003615           NaN          NaN
# 4  fundamentals  reportperiod                           Report Period  ...   0.001766           NaN          NaN
# 5  fundamentals   lastupdated                       Last Updated Date  ...   0.001185           NaN          NaN
# 6  fundamentals        accoci  Accumulated Other Comprehensive Income  ...   0.091696  2.276103e+08      -6000.0
# 7  fundamentals        assets                            Total Assets  ...   0.222871  1.681796e+11  801015000.0
# 8  fundamentals     assetsavg                          Average Assets  ...   0.238474  2.778233e+11  850420000.0
# 9  fundamentals       assetsc                          Current Assets  ...   0.170357  2.019411e+10  187843000.0
#
# [10 rows x 9 columns]

# %% [markdown]
# Let's look at a few tables together. We will eventually add deep dives into each of the tables, but here's a quick look at some of the most important tables first.

# %% [markdown]
# ## Tickers
#
# The tickers table is generally the starting point for most analyses. This table contains all companies, both past and present, as well as a ton of information about them - including both pricing information as well as fundamentals.
