# %% [markdown]
# # Data catalog
#
# In this notebook, we'll explore all the data in Fidap. There are two key tables that contain the metadata -

# %% [markdown]
#  - ``meta_tables`` which contains details about the tables, and
#  - ``meta_fields`` which contains details about the fields

# %%
import fidap, pandas as pd, importlib
importlib.reload(fidap)
# Out:
# <module 'fidap' from 'C:\\Users\\User\\Google Drive\\Python\\notebooks\\fidap.py'>

# %%
fidap.sql("select * from meta_tables")
# Out:
#                    name quandl_code       display_name  \
# 0          fundamentals         SF1       Fundamentals
# 1        insider_trades         SF2     Insider Trades
# 2     portfolio_details         SF3  Portfolio Details
# 3                events      EVENTS             Events
# 4   ticker_shareholders        SF3A            Holders
# 5            portfolios        SF3B         Portfolios
# 6               tickers     TICKERS            Tickers
# 7                 sp500       SP500            S&P 500
# 8               actions     ACTIONS       Corp Actions
# 9                 daily        None      Daily History
# 10                dates        None              Dates
# 11                 corr        None       Correlations
#
#                                    description        rows   cols   datapoints
# 0   This table contains earnings fundamentals.    501353.0  111.0   55650184.0
# 1   This table contains earnings fundamentals.  11901766.0   24.0  285642370.0
# 2   This table contains earnings fundamentals.  34468060.0    7.0  241276420.0
# 3   This table contains earnings fundamentals.    556888.0    3.0    1670664.0
# 4   This table contains earnings fundamentals.    351483.0   29.0   10193007.0
# 5   This table contains earnings fundamentals.    129902.0   28.0    3637256.0
# 6   This table contains earnings fundamentals.      6119.0  204.0    1248276.0
# 7   This table contains earnings fundamentals.     11896.0    7.0      83272.0
# 8   This table contains earnings fundamentals.     17029.0    7.0     119203.0
# 9   This table contains earnings fundamentals.  20689248.0   38.0  786191400.0
# 10  This table contains earnings fundamentals.      1464.0    3.0       4392.0
# 11  This table contains earnings fundamentals.     42940.0    3.0     128820.0

# %% [markdown]
# If we wanted to drill down into any individual table, all we need to do is select the fields from that table, as below -

# %%
fidap.sql('select * from meta_fields where "table" = \'fundamentals\' limit 10')
# Out:
#           table          name                            display_name  \
# 0  fundamentals        ticker                           Ticker Symbol
# 1  fundamentals     dimension                               Dimension
# 2  fundamentals  calendardate                           Calendar Date
# 3  fundamentals       datekey                                Date Key
# 4  fundamentals  reportperiod                           Report Period
# 5  fundamentals   lastupdated                       Last Updated Date
# 6  fundamentals        accoci  Accumulated Other Comprehensive Income
# 7  fundamentals        assets                            Total Assets
# 8  fundamentals     assetsavg                          Average Assets
# 9  fundamentals       assetsc                          Current Assets
#
#                                          description         pd_type  \
# 0  [Entity] The ticker is a unique identifer for ...          object
# 1  [Entity] The dimension field allows you to tak...          object
# 2  "[Entity] The Calendar Date represents the nor...  datetime64[ns]
# 3  [Entity] The Date Key represents the SEC filin...  datetime64[ns]
# 4  [Entity] The Report Period represents the end ...  datetime64[ns]
# 5  [Entity] Last Updated represents the last date...  datetime64[ns]
# 6  [Balance Sheet] A component of [Equity] repres...         float64
# 7  [Balance Sheet] Sum of the carrying amounts as...         float64
# 8  [Metrics] Average asset value for the period u...         float64
# 9  [Balance Sheet] The current portion of [Assets...         float64
#
#    pct_filled  uniqueness          mean       median
# 0    1.000000    0.014525           NaN          NaN
# 1    1.000000    0.000012           NaN          NaN
# 2    1.000000    0.000048           NaN          NaN
# 3    1.000000    0.003572           NaN          NaN
# 4    1.000000    0.001697           NaN          NaN
# 5    1.000000    0.000935           NaN          NaN
# 6    0.988184    0.088959  3.212052e+08     -18000.0
# 7    0.988124    0.224203  1.729413e+11  791227000.0
# 8    0.534059    0.245416  2.810862e+11  829587000.0
# 9    0.781880    0.168941  2.081167e+10  188366990.0

# %% [markdown]
# Let's look at a few tables together. We will eventually add deep dives into each of the tables, but here's a quick look at some of the most important tables first.

# %% [markdown]
# ## Tickers
#
# The tickers table is generally the starting point for most analyses. This table contains all companies, both past and present, as well as a ton of information about them - including both pricing information as well as fundamentals.
